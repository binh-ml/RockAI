# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorboard.plugins.hparams import api as hp

# %%
def load_data(filepath):
    import h5py
    import numpy as np
    h5f = h5py.File(filepath, 'r')
    X = h5f['X'][:]
    classnames = [s.decode('utf-8') for s in h5f['classname'][:]]
    filenames = [s.decode('utf-8') for s in h5f['filename'][:]]
    h5f.close()
    return X, np.array(classnames), np.array(filenames)

def create_train_test_idx(classnames):
    import pandas as pd
    df = pd.DataFrame(data=enumerate(classnames), columns=['index', 'classname'])
    test_df = None
    train_df = None
    for classname in df['classname'].unique():
        test_tmp_df = df[df['classname']==classname].sample(50, replace=False, random_state=1234)
        train_tmp_df = df[(df['classname']==classname) & ~(df['index'].isin(test_tmp_df['index']))]
        test_df = test_tmp_df if test_df is None else pd.concat([test_df, test_tmp_df])
        train_df = train_tmp_df if train_df is None else pd.concat([train_df, train_tmp_df])    
    return train_df['index'].values, test_df['index'].values
    
X, classnames, filenames = load_data('data/RockAI_images_224x224.h5')
train_idx, test_idx = create_train_test_idx(classnames)
X_train, X_test = X[train_idx], X[test_idx]
y_train = [classnames[i] for i in train_idx]
y_test = [classnames[i] for i in test_idx]

num_classes = 2

#Pre-process the data
X_train = tf.keras.applications.resnet50.preprocess_input(X_train)
X_test = tf.keras.applications.resnet50.preprocess_input(X_test)
y_train = [0 if x=='No_RA' else 1 for x in y_train]
y_test = [0 if x=='No_RA' else 1 for x in y_test]
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range = 30,
    horizontal_flip=True,
    vertical_flip=True)
# datagen = tf.keras.preprocessing.image.ImageDataGenerator()
datagen.fit(X_train)

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([256, 512]))
HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.25, 0.5))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam']))

METRIC = 'accuracy'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
    hp.hparams_config(
        hparams=[HP_NUM_UNITS, HP_DROPOUT, HP_OPTIMIZER],
        metrics=[hp.Metric(METRIC, display_name=METRIC)],
    )


def train_test_model(hparams):
    from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
    import time
    import numpy as np
    
    base_model = tf.keras.applications.resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    for layer in base_model.layers[:]:
        layer.trainable = False
        
    model = tf.keras.models.Sequential([
        base_model,        
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(hparams[HP_NUM_UNITS], activation=tf.nn.relu),
        tf.keras.layers.Dropout(hparams[HP_DROPOUT]),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(2, activation=tf.nn.softmax)
    ])
    model.compile(
        loss='categorical_crossentropy',
        optimizer=hparams[HP_OPTIMIZER],        
        metrics=[METRIC],
    )

    start_time = time.time()
    model.fit(X_train, y_train, epochs=10, verbose=1)
    train_time = time.time() - start_time

    start_time = time.time()
    y_pred = model.predict(X_test)
    test_time = time.time() - start_time
    
    y_pred = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_test, axis=1)
    
    C = confusion_matrix(y_true, y_pred)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
        
    return C, acc, f1, train_time, test_time


def run(run_dir, hparams, log_result_filepath):
    import datetime
    
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        C, acc, f1, train_time, test_time = train_test_model(hparams)
        tf.summary.scalar('Accuracy', acc, step=1)
        tf.summary.scalar('F1-score', f1, step=1)
        
    with open(log_result_filepath, 'a') as fp:
        fp.write(f"timestamp: {datetime.datetime.now()}, ")
        for h in hparams:
            fp.write(f"{h.name}: {hparams[h]}, ")
        fp.write("data_augmentation: standard, epochs: 10 \n")
        fp.write(f"\t{str(C)}\n")
        fp.write(f"\tAccuracy: {acc:0.4}, F1-score: {f1:0.4}\n")
        fp.write(f"\tTrain time: {train_time:0.4}, Test_time: {test_time:0.4}\n")

# %%
session_num = 0

for num_units in HP_NUM_UNITS.domain.values:
    for dropout_rate in (HP_DROPOUT.domain.min_value, HP_DROPOUT.domain.max_value):
        for optimizer in HP_OPTIMIZER.domain.values:
            hparams = {
                HP_NUM_UNITS: num_units,
                HP_DROPOUT: dropout_rate,
                HP_OPTIMIZER: optimizer,
            }
            for _ in range(3):
                run_name = "run-%d" % session_num
                print('--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run('logs/hparam_tuning/' + run_name, hparams, 'logs/hparam_tuning_score.txt')
                session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_units': 256, 'dropout': 0.25, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 6s 50ms/step - loss: 0.7805 - accuracy: 0.5983
# Epoch 2/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.3062 - accuracy: 0.8907
# Epoch 3/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.1262 - accuracy: 0.9816
# Epoch 4/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0545 - accuracy: 0.9933
# Epoch 5/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0315 - accuracy: 0.9956
# Epoch 6/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0181 - accuracy: 0.9996
# Epoch 7/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0112 - accuracy: 0.9995
# Epoch 8/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 9/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 10/10
# 43/43 [==============================] - 2s 43ms/step - loss: 0.0053 - accuracy: 1.0000
# --- Starting trial: run-1
# {'num_units': 256, 'dropout': 0.25, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 5s 44ms/step - loss: 0.8155 - accuracy: 0.6047
# Epoch 2/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.2839 - accuracy: 0.9118
# Epoch 3/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.1165 - accuracy: 0.9792
# Epoch 4/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0464 - accuracy: 0.9947
# Epoch 5/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0266 - accuracy: 0.9976
# Epoch 6/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0186 - accuracy: 0.9988
# Epoch 7/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0128 - accuracy: 0.9990
# Epoch 8/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0120 - accuracy: 0.9980
# Epoch 9/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0060 - accuracy: 1.0000
# --- Starting trial: run-2
# {'num_units': 256, 'dropout': 0.25, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 4s 45ms/step - loss: 0.8092 - accuracy: 0.5883
# Epoch 2/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.3096 - accuracy: 0.8871
# Epoch 3/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.1201 - accuracy: 0.9855
# Epoch 4/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0494 - accuracy: 0.9945
# Epoch 5/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0336 - accuracy: 0.9965
# Epoch 6/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0228 - accuracy: 0.9979
# Epoch 7/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 8/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 9/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0050 - accuracy: 1.0000
# --- Starting trial: run-3
# {'num_units': 256, 'dropout': 0.5, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 4s 44ms/step - loss: 0.8392 - accuracy: 0.5598
# Epoch 2/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.3564 - accuracy: 0.8536
# Epoch 3/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.1312 - accuracy: 0.9826
# Epoch 4/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0713 - accuracy: 0.9837
# Epoch 5/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0686 - accuracy: 0.9729
# Epoch 6/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0302 - accuracy: 0.9970
# Epoch 7/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0252 - accuracy: 0.9967
# Epoch 8/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0190 - accuracy: 0.9983
# Epoch 9/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0148 - accuracy: 0.9976
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0226 - accuracy: 0.9936
# --- Starting trial: run-4
# {'num_units': 256, 'dropout': 0.5, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 4s 45ms/step - loss: 0.8092 - accuracy: 0.5756
# Epoch 2/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.3529 - accuracy: 0.8569
# Epoch 3/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.1508 - accuracy: 0.9681
# Epoch 4/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0808 - accuracy: 0.9875
# Epoch 5/10
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0385 - accuracy: 0.9954
# Epoch 6/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0304 - accuracy: 0.9928
# Epoch 7/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0202 - accuracy: 0.9978
# Epoch 8/10
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0212 - accuracy: 0.9966
# Epoch 9/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0145 - accuracy: 0.9972
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0102 - accuracy: 0.9982
# --- Starting trial: run-5
# {'num_units': 256, 'dropout': 0.5, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 4s 45ms/step - loss: 0.8213 - accuracy: 0.5937
# Epoch 2/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.3472 - accuracy: 0.8636
# Epoch 3/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.1304 - accuracy: 0.9792
# Epoch 4/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0674 - accuracy: 0.9897
# Epoch 5/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0469 - accuracy: 0.9919
# Epoch 6/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0358 - accuracy: 0.9904
# Epoch 7/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0251 - accuracy: 0.9925
# Epoch 8/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0223 - accuracy: 0.9969
# Epoch 9/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0145 - accuracy: 0.9977
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0181 - accuracy: 0.9951
# --- Starting trial: run-6
# {'num_units': 512, 'dropout': 0.25, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 4s 45ms/step - loss: 0.8593 - accuracy: 0.5932
# Epoch 2/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.2414 - accuracy: 0.9336
# Epoch 3/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0968 - accuracy: 0.9868
# Epoch 4/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0378 - accuracy: 0.9951
# Epoch 5/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0232 - accuracy: 0.9968
# Epoch 6/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 7/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0106 - accuracy: 0.9993
# Epoch 8/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 9/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0044 - accuracy: 1.0000
# --- Starting trial: run-7
# {'num_units': 512, 'dropout': 0.25, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 4s 45ms/step - loss: 0.8676 - accuracy: 0.6224
# Epoch 2/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.2433 - accuracy: 0.9172
# Epoch 3/10
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0958 - accuracy: 0.9856
# Epoch 4/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0389 - accuracy: 0.9939
# Epoch 5/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0282 - accuracy: 0.9954
# Epoch 6/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0175 - accuracy: 0.9959
# Epoch 7/10
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0091 - accuracy: 0.9999
# Epoch 8/10
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0077 - accuracy: 0.9999
# Epoch 9/10
# 43/43 [==============================] - 2s 47ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 10/10
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0038 - accuracy: 1.0000
# --- Starting trial: run-8
# {'num_units': 512, 'dropout': 0.25, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 4s 44ms/step - loss: 0.7910 - accuracy: 0.6250
# Epoch 2/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.2315 - accuracy: 0.9234
# Epoch 3/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0744 - accuracy: 0.9912
# Epoch 4/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0293 - accuracy: 0.9984
# Epoch 5/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0207 - accuracy: 0.9986
# Epoch 6/10
# 43/43 [==============================] - 2s 46ms/step - loss: 0.0125 - accuracy: 0.9981
# Epoch 7/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0066 - accuracy: 0.9999
# Epoch 8/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0069 - accuracy: 0.9996
# Epoch 9/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0036 - accuracy: 1.0000
# --- Starting trial: run-9
# {'num_units': 512, 'dropout': 0.5, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 4s 44ms/step - loss: 0.7906 - accuracy: 0.5992
# Epoch 2/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.2440 - accuracy: 0.9251
# Epoch 3/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.1112 - accuracy: 0.9761
# Epoch 4/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0457 - accuracy: 0.9876
# Epoch 5/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0341 - accuracy: 0.9890
# Epoch 6/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0196 - accuracy: 0.9983
# Epoch 7/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0157 - accuracy: 0.9960
# Epoch 8/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0105 - accuracy: 0.9989
# Epoch 9/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0070 - accuracy: 0.9997
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0078 - accuracy: 1.0000
# --- Starting trial: run-10
# {'num_units': 512, 'dropout': 0.5, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 4s 45ms/step - loss: 0.7808 - accuracy: 0.6269
# Epoch 2/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.2787 - accuracy: 0.8890
# Epoch 3/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0855 - accuracy: 0.9828
# Epoch 4/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0392 - accuracy: 0.9958
# Epoch 5/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0291 - accuracy: 0.9927
# Epoch 6/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0191 - accuracy: 0.9995
# Epoch 7/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0167 - accuracy: 0.9952
# Epoch 8/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0134 - accuracy: 0.9955
# Epoch 9/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0084 - accuracy: 0.9990
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0072 - accuracy: 0.9992
# --- Starting trial: run-11
# {'num_units': 512, 'dropout': 0.5, 'optimizer': 'adam'}
# Epoch 1/10
# 43/43 [==============================] - 4s 45ms/step - loss: 0.8068 - accuracy: 0.6109
# Epoch 2/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.2395 - accuracy: 0.9042
# Epoch 3/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0874 - accuracy: 0.9828
# Epoch 4/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0458 - accuracy: 0.9896
# Epoch 5/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0317 - accuracy: 0.9942
# Epoch 6/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0207 - accuracy: 0.9961
# Epoch 7/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0182 - accuracy: 0.9981
# Epoch 8/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0144 - accuracy: 0.9958
# Epoch 9/10
# 43/43 [==============================] - 2s 45ms/step - loss: 0.0118 - accuracy: 0.9963
# Epoch 10/10
# 43/43 [==============================] - 2s 44ms/step - loss: 0.0102 - accuracy: 0.9985
