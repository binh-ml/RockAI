# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorboard.plugins.hparams import api as hp

# %%
def load_data(filepath):
    import h5py
    import numpy as np
    h5f = h5py.File(filepath, 'r')
    X = h5f['X'][:]
    classnames = [s.decode('utf-8') for s in h5f['classname'][:]]
    filenames = [s.decode('utf-8') for s in h5f['filename'][:]]
    h5f.close()
    return X, np.array(classnames), np.array(filenames)

def create_train_test_idx(classnames):
    import pandas as pd
    df = pd.DataFrame(data=enumerate(classnames), columns=['index', 'classname'])
    test_df = None
    train_df = None
    for classname in df['classname'].unique():
        test_tmp_df = df[df['classname']==classname].sample(50, replace=False, random_state=1234)
        train_tmp_df = df[(df['classname']==classname) & ~(df['index'].isin(test_tmp_df['index']))]
        test_df = test_tmp_df if test_df is None else pd.concat([test_df, test_tmp_df])
        train_df = train_tmp_df if train_df is None else pd.concat([train_df, train_tmp_df])    
    return train_df['index'].values, test_df['index'].values
    
X, classnames, filenames = load_data('data/RockAI_images_224x224_1358.h5')
train_idx, test_idx = create_train_test_idx(classnames)
X_train, X_test = X[train_idx], X[test_idx]
y_train = [classnames[i] for i in train_idx]
y_test = [classnames[i] for i in test_idx]

num_classes = 2

#Pre-process the data
X_train = tf.keras.applications.densenet.preprocess_input(X_train)
X_test = tf.keras.applications.densenet.preprocess_input(X_test)
y_train = [0 if x=='No_RA' else 1 for x in y_train]
y_test = [0 if x=='No_RA' else 1 for x in y_test]
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range = 30,
    horizontal_flip=True,
    vertical_flip=True)
# datagen = tf.keras.preprocessing.image.ImageDataGenerator()
datagen.fit(X_train)

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([256, 512]))
HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.25, 0.5))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam']))

METRIC = 'accuracy'
num_epochs = 30

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
    hp.hparams_config(
        hparams=[HP_NUM_UNITS, HP_DROPOUT, HP_OPTIMIZER],
        metrics=[hp.Metric(METRIC, display_name=METRIC)],
    )


def train_test_model(hparams):
    from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
    import time
    import numpy as np
        
    model = tf.keras.models.Sequential([        
        tf.keras.layers.Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(224, 224, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_uniform'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(224, 224, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(hparams[HP_NUM_UNITS], activation=tf.nn.relu),        
        tf.keras.layers.Dropout(hparams[HP_DROPOUT]),
        tf.keras.layers.Dense(2, activation=tf.nn.softmax)
    ])
    model.compile(
        loss='categorical_crossentropy',
        optimizer=hparams[HP_OPTIMIZER],        
        metrics=[METRIC],
    )
    print(model.summary())

    start_time = time.time()
    model.fit(X_train, y_train, epochs=num_epochs, verbose=1)
    train_time = time.time() - start_time

    start_time = time.time()
    y_pred = model.predict(X_test)
    test_time = time.time() - start_time
    
    y_pred = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_test, axis=1)
    
    C = confusion_matrix(y_true, y_pred)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
        
    return C, acc, f1, train_time, test_time


def run(run_dir, hparams, log_result_filepath):
    import datetime
    
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        C, acc, f1, train_time, test_time = train_test_model(hparams)
        tf.summary.scalar('Accuracy', acc, step=1)
        tf.summary.scalar('F1-score', f1, step=1)
        
    with open(log_result_filepath, 'a') as fp:
        fp.write(f"timestamp: {datetime.datetime.now()}, ")
        for h in hparams:
            fp.write(f"{h.name}: {hparams[h]}, ")
        fp.write(f"data_augmentation: standard, epochs: {num_epochs} \n")
        fp.write(f"\t{str(C)}\n")
        fp.write(f"\tAccuracy: {acc:0.4}, F1-score: {f1:0.4}\n")
        fp.write(f"\tTrain time: {train_time:0.4}, Test_time: {test_time:0.4}\n")

# %%
session_num = 0

for num_units in HP_NUM_UNITS.domain.values:
    for dropout_rate in (HP_DROPOUT.domain.min_value, HP_DROPOUT.domain.max_value):
        for optimizer in HP_OPTIMIZER.domain.values:
            hparams = {
                HP_NUM_UNITS: num_units,
                HP_DROPOUT: dropout_rate,
                HP_OPTIMIZER: optimizer,
            }
            for _ in range(3):
                run_name = "run-%d" % session_num
                print('--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run('logs/hparam_tuning/' + run_name, hparams, 'logs/hparam_tuning_score.txt')
                session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_units': 256, 'dropout': 0.25, 'optimizer': 'adam'}
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 3200)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               819456
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 918,354
# Trainable params: 918,354
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 47s 629ms/step - loss: 0.7820 - accuracy: 0.8727
# Epoch 2/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.2273 - accuracy: 0.9396
# Epoch 3/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1986 - accuracy: 0.9412
# Epoch 4/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1676 - accuracy: 0.9501
# Epoch 5/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1693 - accuracy: 0.9461
# Epoch 6/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1690 - accuracy: 0.9442
# Epoch 7/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1254 - accuracy: 0.9631
# Epoch 8/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0890 - accuracy: 0.9641
# Epoch 9/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0964 - accuracy: 0.9693
# Epoch 10/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1320 - accuracy: 0.9656
# Epoch 11/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0577 - accuracy: 0.9795
# Epoch 12/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0340 - accuracy: 0.9837
# Epoch 13/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0226 - accuracy: 0.9928
# Epoch 14/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0348 - accuracy: 0.9859
# Epoch 15/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 16/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 17/30
# 40/40 [==============================] - 0s 11ms/step - loss: 9.4627e-04 - accuracy: 1.0000
# Epoch 18/30
# 40/40 [==============================] - 0s 11ms/step - loss: 6.6382e-04 - accuracy: 1.0000
# Epoch 19/30
# 40/40 [==============================] - 0s 11ms/step - loss: 2.8790e-04 - accuracy: 1.0000
# Epoch 20/30
# 40/40 [==============================] - 0s 11ms/step - loss: 1.7236e-04 - accuracy: 1.0000
# Epoch 21/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0073 - accuracy: 0.9979
# Epoch 22/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0376 - accuracy: 0.9859
# Epoch 23/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0184 - accuracy: 0.9955
# Epoch 24/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0183 - accuracy: 0.9954
# Epoch 26/30
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0377 - accuracy: 0.9847
# Epoch 27/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0195 - accuracy: 0.9975
# Epoch 28/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 29/30
# 40/40 [==============================] - 0s 11ms/step - loss: 5.0616e-04 - accuracy: 1.0000
# Epoch 30/30
# 40/40 [==============================] - 0s 11ms/step - loss: 3.1599e-04 - accuracy: 1.0000
# --- Starting trial: run-1
# {'num_units': 256, 'dropout': 0.25, 'optimizer': 'adam'}
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               819456
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 918,354
# Trainable params: 918,354
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 14ms/step - loss: 0.7186 - accuracy: 0.9488
# Epoch 2/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.2490 - accuracy: 0.9292
# Epoch 3/30
# 40/40 [==============================] - 0s 12ms/step - loss: 0.1689 - accuracy: 0.9358
# Epoch 4/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1884 - accuracy: 0.9457
# Epoch 5/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1032 - accuracy: 0.9592
# Epoch 6/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1136 - accuracy: 0.9543
# Epoch 7/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1119 - accuracy: 0.9596
# Epoch 8/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0871 - accuracy: 0.9694
# Epoch 9/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0518 - accuracy: 0.9791
# Epoch 10/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0372 - accuracy: 0.9836
# Epoch 11/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0308 - accuracy: 0.9910
# Epoch 12/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0061 - accuracy: 0.9990
# Epoch 13/30
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0053 - accuracy: 0.9990
# Epoch 14/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0064 - accuracy: 0.9967
# Epoch 15/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0440 - accuracy: 0.9828
# Epoch 16/30
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0299 - accuracy: 0.9868
# Epoch 17/30
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 0.9999
# Epoch 18/30
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0102 - accuracy: 0.9986
# Epoch 19/30
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 20/30
# 40/40 [==============================] - 0s 12ms/step - loss: 6.8452e-04 - accuracy: 1.0000
# Epoch 21/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 22/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 23/30
# 40/40 [==============================] - 0s 11ms/step - loss: 6.3232e-04 - accuracy: 1.0000
# Epoch 24/30
# 40/40 [==============================] - 0s 11ms/step - loss: 3.1636e-04 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 11ms/step - loss: 9.2992e-05 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 11ms/step - loss: 1.4208e-04 - accuracy: 1.0000
# Epoch 27/30
# 40/40 [==============================] - 0s 12ms/step - loss: 5.9244e-05 - accuracy: 1.0000
# Epoch 28/30
# 40/40 [==============================] - 0s 11ms/step - loss: 4.3246e-05 - accuracy: 1.0000
# Epoch 29/30
# 40/40 [==============================] - 0s 11ms/step - loss: 4.9415e-05 - accuracy: 1.0000
# Epoch 30/30
# 40/40 [==============================] - 0s 10ms/step - loss: 5.0021e-05 - accuracy: 1.0000
# --- Starting trial: run-2
# {'num_units': 256, 'dropout': 0.25, 'optimizer': 'adam'}
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               819456
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 918,354
# Trainable params: 918,354
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 10ms/step - loss: 0.7340 - accuracy: 0.9213
# Epoch 2/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1615 - accuracy: 0.9545
# Epoch 3/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1724 - accuracy: 0.9361
# Epoch 4/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1495 - accuracy: 0.9606
# Epoch 5/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1285 - accuracy: 0.9536
# Epoch 6/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1180 - accuracy: 0.9586
# Epoch 7/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0738 - accuracy: 0.9704
# Epoch 8/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0637 - accuracy: 0.9816
# Epoch 9/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0328 - accuracy: 0.9831
# Epoch 10/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0250 - accuracy: 0.9932
# Epoch 11/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0442 - accuracy: 0.9911
# Epoch 12/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0180 - accuracy: 0.9906
# Epoch 13/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 14/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 15/30
# 40/40 [==============================] - 0s 11ms/step - loss: 9.0205e-04 - accuracy: 1.0000
# Epoch 16/30
# 40/40 [==============================] - 0s 11ms/step - loss: 4.8601e-04 - accuracy: 1.0000
# Epoch 17/30
# 40/40 [==============================] - 0s 11ms/step - loss: 4.7446e-04 - accuracy: 1.0000
# Epoch 18/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0390 - accuracy: 0.9890
# Epoch 19/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1425 - accuracy: 0.9473
# Epoch 20/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0226 - accuracy: 0.9954
# Epoch 21/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 22/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 23/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 24/30
# 40/40 [==============================] - 0s 11ms/step - loss: 6.6990e-04 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 11ms/step - loss: 3.2195e-04 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 11ms/step - loss: 1.5542e-04 - accuracy: 1.0000
# Epoch 27/30
# 40/40 [==============================] - 0s 11ms/step - loss: 1.5880e-04 - accuracy: 1.0000
# Epoch 28/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.6453e-04 - accuracy: 1.0000
# Epoch 29/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.1266e-04 - accuracy: 1.0000
# Epoch 30/30
# 40/40 [==============================] - 0s 10ms/step - loss: 7.0837e-05 - accuracy: 1.0000
# --- Starting trial: run-3
# {'num_units': 256, 'dropout': 0.5, 'optimizer': 'adam'}
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               819456
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 918,354
# Trainable params: 918,354
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 11ms/step - loss: 1.2406 - accuracy: 0.8855
# Epoch 2/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.2387 - accuracy: 0.9388
# Epoch 3/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1869 - accuracy: 0.9435
# Epoch 4/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1590 - accuracy: 0.9491
# Epoch 5/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1346 - accuracy: 0.9571
# Epoch 6/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1446 - accuracy: 0.9473
# Epoch 7/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1238 - accuracy: 0.9531
# Epoch 8/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1266 - accuracy: 0.9629
# Epoch 9/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0946 - accuracy: 0.9697
# Epoch 10/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1004 - accuracy: 0.9618
# Epoch 11/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0793 - accuracy: 0.9722
# Epoch 12/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0827 - accuracy: 0.9696
# Epoch 13/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0765 - accuracy: 0.9731
# Epoch 14/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0479 - accuracy: 0.9887
# Epoch 15/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0443 - accuracy: 0.9809
# Epoch 16/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0286 - accuracy: 0.9924
# Epoch 17/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0188 - accuracy: 0.9929
# Epoch 18/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0130 - accuracy: 0.9947
# Epoch 19/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0064 - accuracy: 0.9993
# Epoch 20/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 21/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0040 - accuracy: 0.9979
# Epoch 22/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0054 - accuracy: 0.9979
# Epoch 23/30
# 40/40 [==============================] - 0s 10ms/step - loss: 8.6305e-04 - accuracy: 1.0000
# Epoch 24/30
# 40/40 [==============================] - 0s 10ms/step - loss: 7.5597e-04 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 10ms/step - loss: 3.7931e-04 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 0.9999
# Epoch 27/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0087 - accuracy: 0.9976
# Epoch 28/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0943 - accuracy: 0.9761
# Epoch 29/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0259 - accuracy: 0.9921
# Epoch 30/30
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0111 - accuracy: 0.9956
# --- Starting trial: run-4
# {'num_units': 256, 'dropout': 0.5, 'optimizer': 'adam'}
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               819456
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 918,354
# Trainable params: 918,354
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 10ms/step - loss: 0.9467 - accuracy: 0.9012
# Epoch 2/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.2080 - accuracy: 0.9490
# Epoch 3/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1503 - accuracy: 0.9515
# Epoch 4/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1492 - accuracy: 0.9483
# Epoch 5/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1233 - accuracy: 0.9570
# Epoch 6/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1271 - accuracy: 0.9532
# Epoch 7/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1126 - accuracy: 0.9531
# Epoch 8/30
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0760 - accuracy: 0.9723
# Epoch 9/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0652 - accuracy: 0.9700
# Epoch 10/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0569 - accuracy: 0.9777
# Epoch 11/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0989 - accuracy: 0.9698
# Epoch 12/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0455 - accuracy: 0.9844
# Epoch 13/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0067 - accuracy: 0.9985
# Epoch 14/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0182 - accuracy: 0.9926
# Epoch 15/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0109 - accuracy: 0.9973
# Epoch 16/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0242 - accuracy: 0.9953
# Epoch 17/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0070 - accuracy: 0.9948
# Epoch 18/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0077 - accuracy: 0.9952
# Epoch 19/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 20/30
# 40/40 [==============================] - 0s 10ms/step - loss: 5.7036e-04 - accuracy: 1.0000
# Epoch 21/30
# 40/40 [==============================] - 0s 10ms/step - loss: 5.3738e-04 - accuracy: 1.0000
# Epoch 22/30
# 40/40 [==============================] - 0s 10ms/step - loss: 3.9986e-04 - accuracy: 1.0000
# Epoch 23/30
# 40/40 [==============================] - 0s 11ms/step - loss: 6.5875e-04 - accuracy: 1.0000
# Epoch 24/30
# 40/40 [==============================] - 0s 11ms/step - loss: 4.1998e-04 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 10ms/step - loss: 2.6889e-04 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 12ms/step - loss: 1.4371e-04 - accuracy: 1.0000
# Epoch 27/30
# 40/40 [==============================] - 0s 11ms/step - loss: 1.0098e-04 - accuracy: 1.0000
# Epoch 28/30
# 40/40 [==============================] - 0s 11ms/step - loss: 2.5962e-04 - accuracy: 1.0000
# Epoch 29/30
# 40/40 [==============================] - 0s 11ms/step - loss: 6.4937e-04 - accuracy: 1.0000
# Epoch 30/30
# 40/40 [==============================] - 0s 11ms/step - loss: 4.9807e-04 - accuracy: 1.0000
# --- Starting trial: run-5
# {'num_units': 256, 'dropout': 0.5, 'optimizer': 'adam'}
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               819456
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 514
# =================================================================
# Total params: 918,354
# Trainable params: 918,354
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 10ms/step - loss: 0.9999 - accuracy: 0.9251
# Epoch 2/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.2035 - accuracy: 0.9403
# Epoch 3/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1800 - accuracy: 0.9490
# Epoch 4/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1424 - accuracy: 0.9560
# Epoch 5/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1397 - accuracy: 0.9605
# Epoch 6/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1166 - accuracy: 0.9558
# Epoch 7/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1087 - accuracy: 0.9584
# Epoch 8/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0642 - accuracy: 0.9792
# Epoch 9/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0420 - accuracy: 0.9846
# Epoch 10/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0354 - accuracy: 0.9898
# Epoch 11/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0270 - accuracy: 0.9895
# Epoch 12/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0614 - accuracy: 0.9743
# Epoch 13/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0398 - accuracy: 0.9833
# Epoch 14/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0159 - accuracy: 0.9944
# Epoch 15/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0103 - accuracy: 0.9969
# Epoch 16/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0264 - accuracy: 0.9882
# Epoch 17/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0178 - accuracy: 0.9935
# Epoch 18/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0202 - accuracy: 0.9934
# Epoch 19/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 20/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 21/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 22/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 23/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 24/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 10ms/step - loss: 6.9298e-04 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 0.9999
# Epoch 27/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0510 - accuracy: 0.9831
# Epoch 28/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0479 - accuracy: 0.9889
# Epoch 29/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0289 - accuracy: 0.9872
# Epoch 30/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0131 - accuracy: 0.9945
# --- Starting trial: run-6
# {'num_units': 512, 'dropout': 0.25, 'optimizer': 'adam'}
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               1638912
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 1,738,322
# Trainable params: 1,738,322
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 10ms/step - loss: 1.6505 - accuracy: 0.8688
# Epoch 2/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1851 - accuracy: 0.9482
# Epoch 3/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1526 - accuracy: 0.9513
# Epoch 4/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1403 - accuracy: 0.9578
# Epoch 5/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1907 - accuracy: 0.9345
# Epoch 6/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1216 - accuracy: 0.9584
# Epoch 7/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1067 - accuracy: 0.9609
# Epoch 8/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0889 - accuracy: 0.9697
# Epoch 9/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1103 - accuracy: 0.9566
# Epoch 10/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0585 - accuracy: 0.9785
# Epoch 11/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0414 - accuracy: 0.9892
# Epoch 12/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0239 - accuracy: 0.9900
# Epoch 13/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0074 - accuracy: 0.9987
# Epoch 14/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0115 - accuracy: 0.9955
# Epoch 15/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0147 - accuracy: 0.9961
# Epoch 16/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0104 - accuracy: 0.9955
# Epoch 17/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0079 - accuracy: 0.9987
# Epoch 18/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 19/30
# 40/40 [==============================] - 0s 11ms/step - loss: 3.8835e-04 - accuracy: 1.0000
# Epoch 20/30
# 40/40 [==============================] - 0s 10ms/step - loss: 3.0486e-04 - accuracy: 1.0000
# Epoch 21/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.4790e-04 - accuracy: 1.0000
# Epoch 22/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.0780e-04 - accuracy: 1.0000
# Epoch 23/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.2951e-04 - accuracy: 1.0000
# Epoch 24/30
# 40/40 [==============================] - 0s 10ms/step - loss: 6.5938e-05 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 10ms/step - loss: 7.9985e-05 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 10ms/step - loss: 6.6465e-05 - accuracy: 1.0000
# Epoch 27/30
# 40/40 [==============================] - 0s 10ms/step - loss: 5.3857e-05 - accuracy: 1.0000
# Epoch 28/30
# 40/40 [==============================] - 0s 10ms/step - loss: 4.9195e-05 - accuracy: 1.0000
# Epoch 29/30
# 40/40 [==============================] - 0s 10ms/step - loss: 3.5246e-05 - accuracy: 1.0000
# Epoch 30/30
# 40/40 [==============================] - 0s 9ms/step - loss: 4.2198e-05 - accuracy: 1.0000
# --- Starting trial: run-7
# {'num_units': 512, 'dropout': 0.25, 'optimizer': 'adam'}
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_35 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               1638912
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 1,738,322
# Trainable params: 1,738,322
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 10ms/step - loss: 2.4192 - accuracy: 0.8425
# Epoch 2/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1997 - accuracy: 0.9458
# Epoch 3/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1898 - accuracy: 0.9462
# Epoch 4/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1450 - accuracy: 0.9522
# Epoch 5/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1479 - accuracy: 0.9483
# Epoch 6/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1794 - accuracy: 0.9430
# Epoch 7/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1076 - accuracy: 0.9637
# Epoch 8/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1159 - accuracy: 0.9609
# Epoch 9/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0826 - accuracy: 0.9704
# Epoch 10/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0994 - accuracy: 0.9700
# Epoch 11/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0843 - accuracy: 0.9738
# Epoch 12/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0435 - accuracy: 0.9797
# Epoch 13/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0786 - accuracy: 0.9725
# Epoch 14/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0265 - accuracy: 0.9912
# Epoch 15/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0123 - accuracy: 0.9966
# Epoch 16/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 17/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 18/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 19/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 20/30
# 40/40 [==============================] - 0s 10ms/step - loss: 4.4183e-04 - accuracy: 1.0000
# Epoch 21/30
# 40/40 [==============================] - 0s 10ms/step - loss: 4.2062e-04 - accuracy: 1.0000
# Epoch 22/30
# 40/40 [==============================] - 0s 10ms/step - loss: 2.9567e-04 - accuracy: 1.0000
# Epoch 23/30
# 40/40 [==============================] - 0s 10ms/step - loss: 2.2184e-04 - accuracy: 1.0000
# Epoch 24/30
# 40/40 [==============================] - 0s 10ms/step - loss: 2.2272e-04 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.7207e-04 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.6584e-04 - accuracy: 1.0000
# Epoch 27/30
# 40/40 [==============================] - 0s 10ms/step - loss: 2.0451e-04 - accuracy: 1.0000
# Epoch 28/30
# 40/40 [==============================] - 0s 10ms/step - loss: 9.5260e-05 - accuracy: 1.0000
# Epoch 29/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.2525e-04 - accuracy: 1.0000
# Epoch 30/30
# 40/40 [==============================] - 0s 9ms/step - loss: 9.8798e-05 - accuracy: 1.0000
# --- Starting trial: run-8
# {'num_units': 512, 'dropout': 0.25, 'optimizer': 'adam'}
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_40 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               1638912
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 1,738,322
# Trainable params: 1,738,322
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 11ms/step - loss: 1.2568 - accuracy: 0.8756
# Epoch 2/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1866 - accuracy: 0.9504
# Epoch 3/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1916 - accuracy: 0.9390
# Epoch 4/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1255 - accuracy: 0.9672
# Epoch 5/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1504 - accuracy: 0.9588
# Epoch 6/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1285 - accuracy: 0.9519
# Epoch 7/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1082 - accuracy: 0.9689
# Epoch 8/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0899 - accuracy: 0.9757
# Epoch 9/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0530 - accuracy: 0.9834
# Epoch 10/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0498 - accuracy: 0.9806
# Epoch 11/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0425 - accuracy: 0.9843
# Epoch 12/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0165 - accuracy: 0.9966
# Epoch 13/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0195 - accuracy: 0.9941
# Epoch 14/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0121 - accuracy: 0.9971
# Epoch 15/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0071 - accuracy: 0.9995
# Epoch 16/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0040 - accuracy: 0.9985
# Epoch 17/30
# 40/40 [==============================] - 0s 10ms/step - loss: 8.5848e-04 - accuracy: 1.0000
# Epoch 18/30
# 40/40 [==============================] - 0s 10ms/step - loss: 3.4674e-04 - accuracy: 1.0000
# Epoch 19/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.7385e-04 - accuracy: 1.0000
# Epoch 20/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.5729e-04 - accuracy: 1.0000
# Epoch 21/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.1024e-04 - accuracy: 1.0000
# Epoch 22/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.1929e-04 - accuracy: 1.0000
# Epoch 23/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.1133e-04 - accuracy: 1.0000
# Epoch 24/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.0838e-04 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 10ms/step - loss: 7.2401e-05 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 10ms/step - loss: 7.6061e-05 - accuracy: 1.0000
# Epoch 27/30
# 40/40 [==============================] - 0s 11ms/step - loss: 7.6025e-05 - accuracy: 1.0000
# Epoch 28/30
# 40/40 [==============================] - 0s 10ms/step - loss: 6.4094e-05 - accuracy: 1.0000
# Epoch 29/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.5003e-04 - accuracy: 1.0000
# Epoch 30/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0018 - accuracy: 0.9994
# --- Starting trial: run-9
# {'num_units': 512, 'dropout': 0.5, 'optimizer': 'adam'}
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_45 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               1638912
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 1,738,322
# Trainable params: 1,738,322
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 10ms/step - loss: 0.6979 - accuracy: 0.9042
# Epoch 2/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.1779 - accuracy: 0.9414
# Epoch 3/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1605 - accuracy: 0.9424
# Epoch 4/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1485 - accuracy: 0.9560
# Epoch 5/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1334 - accuracy: 0.9472 0s - loss: 0.1566 - accu
# Epoch 6/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1172 - accuracy: 0.9577
# Epoch 7/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1033 - accuracy: 0.9619
# Epoch 8/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0577 - accuracy: 0.9799
# Epoch 9/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0442 - accuracy: 0.9831
# Epoch 10/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0563 - accuracy: 0.9794
# Epoch 11/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0346 - accuracy: 0.9877
# Epoch 12/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0356 - accuracy: 0.9900
# Epoch 13/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0330 - accuracy: 0.9881
# Epoch 14/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0143 - accuracy: 0.9976
# Epoch 15/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0072 - accuracy: 0.9979
# Epoch 16/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0120 - accuracy: 0.9974
# Epoch 17/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0406 - accuracy: 0.9841
# Epoch 18/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0280 - accuracy: 0.9911
# Epoch 19/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0204 - accuracy: 0.9929
# Epoch 20/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0158 - accuracy: 0.9967
# Epoch 21/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0053 - accuracy: 0.9961
# Epoch 22/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 23/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 24/30
# 40/40 [==============================] - 0s 10ms/step - loss: 2.1243e-04 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 10ms/step - loss: 2.0665e-04 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.6088e-04 - accuracy: 1.0000
# Epoch 27/30
# 40/40 [==============================] - 0s 10ms/step - loss: 2.4701e-04 - accuracy: 1.0000
# Epoch 28/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 29/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.1823e-04 - accuracy: 1.0000
# Epoch 30/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.3434e-04 - accuracy: 1.0000
# --- Starting trial: run-10
# {'num_units': 512, 'dropout': 0.5, 'optimizer': 'adam'}
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_50 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_52 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_53 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_54 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 3200)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               1638912
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 1,738,322
# Trainable params: 1,738,322
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 10ms/step - loss: 1.2683 - accuracy: 0.8783
# Epoch 2/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1936 - accuracy: 0.9433
# Epoch 3/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1949 - accuracy: 0.9405
# Epoch 4/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1639 - accuracy: 0.9440
# Epoch 5/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1385 - accuracy: 0.9555
# Epoch 6/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1088 - accuracy: 0.9664
# Epoch 7/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1017 - accuracy: 0.9581
# Epoch 8/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0728 - accuracy: 0.9700
# Epoch 9/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0551 - accuracy: 0.9814
# Epoch 10/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0662 - accuracy: 0.9805
# Epoch 11/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0311 - accuracy: 0.9910
# Epoch 12/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0171 - accuracy: 0.9934
# Epoch 13/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0354 - accuracy: 0.9907
# Epoch 14/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0132 - accuracy: 0.9978
# Epoch 15/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0051 - accuracy: 0.9977
# Epoch 16/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0046 - accuracy: 0.9979
# Epoch 17/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0048 - accuracy: 0.9975
# Epoch 18/30
# 40/40 [==============================] - 0s 10ms/step - loss: 8.8067e-04 - accuracy: 1.0000
# Epoch 19/30
# 40/40 [==============================] - 0s 10ms/step - loss: 9.3464e-04 - accuracy: 1.0000
# Epoch 20/30
# 40/40 [==============================] - 0s 10ms/step - loss: 4.0925e-04 - accuracy: 1.0000
# Epoch 21/30
# 40/40 [==============================] - 0s 10ms/step - loss: 2.9543e-04 - accuracy: 1.0000
# Epoch 22/30
# 40/40 [==============================] - 0s 10ms/step - loss: 8.9443e-05 - accuracy: 1.0000
# Epoch 23/30
# 40/40 [==============================] - 0s 10ms/step - loss: 2.0665e-04 - accuracy: 1.0000
# Epoch 24/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.5573e-04 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 10ms/step - loss: 1.1251e-04 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 10ms/step - loss: 9.9756e-05 - accuracy: 1.0000
# Epoch 27/30
# 40/40 [==============================] - 0s 10ms/step - loss: 4.9448e-05 - accuracy: 1.0000
# Epoch 28/30
# 40/40 [==============================] - 0s 10ms/step - loss: 7.1443e-05 - accuracy: 1.0000
# Epoch 29/30
# 40/40 [==============================] - 0s 10ms/step - loss: 6.1783e-05 - accuracy: 1.0000
# Epoch 30/30
# 40/40 [==============================] - 0s 9ms/step - loss: 7.1536e-05 - accuracy: 1.0000
# --- Starting trial: run-11
# {'num_units': 512, 'dropout': 0.5, 'optimizer': 'adam'}
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_55 (Conv2D)           (None, 222, 222, 8)       224
# _________________________________________________________________
# max_pooling2d_55 (MaxPooling (None, 111, 111, 8)       0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 109, 109, 16)      1168
# _________________________________________________________________
# max_pooling2d_56 (MaxPooling (None, 54, 54, 16)        0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 52, 52, 32)        4640
# _________________________________________________________________
# max_pooling2d_57 (MaxPooling (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_58 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_59 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 3200)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               1638912
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 1,738,322
# Trainable params: 1,738,322
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 40/40 [==============================] - 1s 11ms/step - loss: 1.9121 - accuracy: 0.8504
# Epoch 2/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.2105 - accuracy: 0.9457
# Epoch 3/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1726 - accuracy: 0.9487
# Epoch 4/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1420 - accuracy: 0.9544
# Epoch 5/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1574 - accuracy: 0.9484
# Epoch 6/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1343 - accuracy: 0.9572
# Epoch 7/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1260 - accuracy: 0.9569
# Epoch 8/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0870 - accuracy: 0.9681
# Epoch 9/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0722 - accuracy: 0.9766
# Epoch 10/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0623 - accuracy: 0.9764
# Epoch 11/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0525 - accuracy: 0.9800
# Epoch 12/30
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0659 - accuracy: 0.9826
# Epoch 13/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0283 - accuracy: 0.9853
# Epoch 14/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0239 - accuracy: 0.9908
# Epoch 15/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0163 - accuracy: 0.9964
# Epoch 16/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 17/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0031 - accuracy: 0.9994
# Epoch 18/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 19/30
# 40/40 [==============================] - 0s 11ms/step - loss: 9.9830e-04 - accuracy: 1.0000
# Epoch 20/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0038 - accuracy: 0.9986
# Epoch 21/30
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 22/30
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 23/30
# 40/40 [==============================] - 0s 11ms/step - loss: 3.3614e-04 - accuracy: 1.0000
# Epoch 24/30
# 40/40 [==============================] - 0s 11ms/step - loss: 2.9179e-04 - accuracy: 1.0000
# Epoch 25/30
# 40/40 [==============================] - 0s 11ms/step - loss: 2.1054e-04 - accuracy: 1.0000
# Epoch 26/30
# 40/40 [==============================] - 0s 11ms/step - loss: 3.6733e-04 - accuracy: 1.0000
# Epoch 27/30
# 40/40 [==============================] - 0s 11ms/step - loss: 1.4671e-04 - accuracy: 1.0000
# Epoch 28/30
# 40/40 [==============================] - 0s 11ms/step - loss: 1.0938e-04 - accuracy: 1.0000
# Epoch 29/30
# 40/40 [==============================] - 0s 11ms/step - loss: 7.8789e-05 - accuracy: 1.0000
# Epoch 30/30
# 40/40 [==============================] - 0s 10ms/step - loss: 9.0487e-05 - accuracy: 1.0000
